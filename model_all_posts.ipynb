# %%
#pip install nltk
#pip install spacy
#python -m spacy download da_core_news_sm

#pip install gensim
#pip install pyLDAvis

import json
import pandas as pd
import spacy
import re
import nltk
#nltk.download('stopwords')
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize
#nltk.download('punkt')
import codecs
import sys


import pathlib
from pathlib import Path
import os

import gensim
from gensim.models import CoherenceModel, LdaModel, LsiModel, HdpModel
from gensim.corpora import Dictionary

import pyLDAvis.gensim_models
import pyLDAvis.sklearn
#pyLDAvis.enable_notebook()

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.decomposition import LatentDirichletAllocation

# %%
def change_letter(dataset: pd.DataFrame) -> list:
    new_dataset = [re.sub('ø', 'oe', text) for text in dataset]
    new_dataset = [re.sub('æ', 'ae', text) for text in new_dataset]
    new_dataset = [re.sub('å', 'aa', text) for text in new_dataset]
    new_dataset = [re.sub('Ø', 'oe', text) for text in new_dataset]
    new_dataset = [re.sub('Æ', 'ae', text) for text in new_dataset]
    new_dataset = [re.sub('Å', 'aa', text) for text in new_dataset]
    new_dataset = [re.sub('ü', 'ue', text) for text in new_dataset]
    new_dataset = [re.sub('Ü', 'ue', text) for text in new_dataset]
    new_dataset = [re.sub('ä', 'ae', text) for text in new_dataset]
    new_dataset = [re.sub('Ä', 'ae', text) for text in new_dataset]
    new_dataset = [re.sub('ö', 'oe', text) for text in new_dataset]
    new_dataset = [re.sub('Ö', 'oe', text) for text in new_dataset]
    
    return new_dataset

# %%
def get_clean_text(dataset: list, stops_da, stops_en) -> list:
    no_urls = [re.sub(r"http\S+", "", text) for text in dataset] 
    only_letters = [re.sub(r"(#[A-Za-z]+)|(@[A-Za-z]+)|([^A-Za-z \t])|(\w+:\/\/\S+)", ' ' , text) for text in no_urls] 
    only_letters = [text.replace('\n', ' ') for text in only_letters]
    lowercased_str = [text.lower().split() for text in only_letters] 
    no_stopwords = [[w for w in text if not w in stops_da] for text in lowercased_str] 
    no_stopwords = [[w for w in text if not w in stops_en] for text in no_stopwords] 
    cleaned_text = [" ".join(text) for text in no_stopwords] 
    return cleaned_text

# %%
def tokenize_text(data):
    tokens = [word_tokenize(text) for text in data] 
    return tokens

# %%
def lemmatize_text(sent):
    lemmas = [x.lemma_ for x in nlp(sent)]
    return lemmas

# %%
def lemmatize_posts(tokenized_data: list):
    lemmas = []
    for post in tokenized_data:
        lemma = [lemmatize_text(x) for x in post]
        lemmas.append([item for sublist in lemma for item in sublist])
    return lemmas

# %%
def decode(path: str) -> list:

    f = codecs.open(path, errors = 'ignore', encoding = 'utf-8')
    data = f.read()
    data = data.encode('latin1').decode('utf8')
    data = data.splitlines()  
    return data

# %%
def remove_mentions(dataset: list):
    new_dataset = []
    for i in dataset:
        if i.startswith('@'):
          i = i.replace(i, "")
        new_dataset.append(i)
    return new_dataset

# %%
decoded_data = decode('data/JSON_files/prepared_txt/all_data.txt')

print(len(decoded_data))
# Out:
# 27483

# %%
new_data = remove_mentions(decoded_data)

print(len(new_data))
# Out:
# 27483

# %%
without_empty_strings = [string for string in new_data if string != ""]

print(len(without_empty_strings))
# Out:
# 27277

# %%
df = pd.DataFrame(without_empty_strings, columns=['row_posts'])

# %%
nlp = spacy.load("da_core_news_sm")
stopwords_da = stopwords.words("danish")  
stopwords_da.extend(['paa', 'saa', 'vaere',  'rt', 'ogsaa', 'faa', 'faar', 'nok', 'mt', 'gt'])

# %%
nlp1 = spacy.load("en_core_web_sm")
stopwords_en = stopwords.words("english")

# %%
fb_posts = change_letter(df['row_posts'])

# %%
cleaned_posts = get_clean_text(fb_posts, stops_da = stopwords_da, stops_en = stopwords_en)

# %%
remove_empty_strings = [string for string in cleaned_posts if string != ""]

# %%
tokenized_posts = tokenize_text(remove_empty_strings)

# %%
lemmatized_posts = lemmatize_posts(tokenized_posts)

# %%
df1 = pd.DataFrame(remove_empty_strings , columns=['cleaned_posts'])

df1['tokenized_posts'] = tokenized_posts
df1['lemmatized_posts'] = lemmatized_posts

# %%
df1.to_pickle('data/all_posts_df.pkl')

# %%
#df1 = pd.read_pickle('data/all_posts_df.pkl')

# %%
bigram = gensim.models.Phrases(df1['lemmatized_posts'])
posts_bigrams = [bigram[line] for line in df1['lemmatized_posts']]

# %%
dictionary = Dictionary(posts_bigrams)
corpus = [dictionary.doc2bow(text) for text in posts_bigrams]

# %%
ldamodel = LdaModel(corpus = corpus, 
                    num_topics =  6, 
                    id2word = dictionary,
                    update_every = 1,
                    passes = 10,
                    per_word_topics = True)

# %%
pyLDAvis.enable_notebook()
model =pyLDAvis.gensim_models.prepare(ldamodel, corpus, dictionary)
pyLDAvis.display(model)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.3.1/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el374581404068265624966390116283"></div>
# <script type="text/javascript">
#
# var ldavis_el374581404068265624966390116283_data = {"mdsDat": {"x": [0.2352467130932012, 0.2204024880314105, -0.24587526865585127, -0.019494240242984476, -0.03503887083331417, -0.1552408213924615], "y": [-0.1437293277688165, 0.017710816680881848, -0.2443152714668288, 0.040169424650114985, 0.1819880566909844, 0.14817630121366368], "topics": [1, 2, 3, 4, 5, 6], "cluster": [1, 1, 1, 1, 1, 1], "Freq": [33.089507784050696, 22.0843426337999, 17.991465294866906, 10.666753271197138, 9.545700533315028, 6.6222304827703375]}, "tinfo": {"Term": ["dag", "lig_tillykke", "tillykke", "tillykke_foedselsdagen", "mae_daw", "dejlig", "vide", "kunne", "hurra", "ven", "kaere", "komme", "hygge", "god", "stor_tillykke", "tak", "hip_hip", "naar", "lykke", "hjertelig_lykke", "smuk", "le", "nyde", "haaber", "stor", "foedselsdagen", "daw", "lig_tillyk", "sige", "video", "naar", "sige", "anden", "sf", "kl", "arbejde", "gerne", "nogen", "bruge", "boern", "uden", "verden", "flere", "mand", "tro", "komme", "syne", "sted", "ingen", "hvem", "staar", "bo", "brug", "pige", "hvorfor", "gaa", "skole", "hjaelp", "handle", "nytte", "vide", "tag", "kun", "kunne", "mere", "bare", "vores", "ny", "se", "baade", "menneske", "gang", "lige", "finde", "godte", "give", "lille", "igen", "lidt", "liv", "tid", "god", "tillykke", "kaere", "dejlig", "hygge", "stor_tillykke", "lykke", "hjertelig_lykke", "nyde", "haaber", "foedselsdagen", "dag", "hjertelig_tillykke", "dejlig_dag", "soede", "tillyk_mae", "foedselsdag", "mor_datter", "glaeder", "foedselsdagen_haaber", "dreng", "lav", "fejre", "aar_side", "kaereste", "ven", "kaeresten", "skoenne", "haaber_have", "haaber_dejlig", "hilse", "tak", "gave", "daw", "god", "stor", "gaar", "sammen", "aar", "fantastisk", "familie", "igen", "godte", "lige", "lille", "people", "world", "one", "e", "happy_birthday", "new", "mae", "la", "plan", "food", "r", "day", "solar", "said", "penge", "africa", "also", "made", "life", "us", "house", "energy", "power", "beautiful", "global", "make", "water", "african", "see", "good", "fredag", "tog", "burkina_faso", "ligge", "time", "million", "video", "projekt", "like", "facebook", "aeldre", "saette", "kraeft", "part", "deltage", "frivillig", "hinanden", "kaemper", "international", "familie_ven", "kopiere", "sikre", "hedde", "maria", "city", "ramme", "system", "venlig", "take", "bl", "enig", "forskellig", "status", "laeser", "faktisk", "gammel_ven", "women", "rette", "vigtig", "fordi", "samme", "goer", "stemme", "skrive", "kunne", "se", "afrikansk_marked", "lig_tillykke", "danmark", "klare", "varme", "so", "soes", "gaaet", "tillykke_mae", "nemlig", "rigtig_dejlig", "foto", "trine", "nej", "oensker_dejlig", "ebbesen", "udsigt", "ble", "snakke", "enkelt", "videre", "samtidig", "soeger", "slette", "taenk", "haaber_rigtig", "rejse", "hver_dag", "solskin", "forening", "osse", "kr", "mae_daw", "smuk", "tale", "foer", "n", "kvinde", "kolding", "daw", "tillykke_foedselsdagen", "hurra", "hip_hip", "le", "lig_tillyk", "soedde", "hilse_trine", "des", "laes", "hanne", "pour", "lykke_kaere", "une", "soeren", "idag", "boernene", "tillykke_allerbedste", "qui", "trine_maria", "ide", "ce", "soendag_okt", "est", "sand", "ja_ja", "sep_kl", "dupont_ebbesen", "au", "jamen", "moeder", "knus_trine", "l", "un", "mae_daw", "hej", "parre", "afrikansk_marked"], "Freq": [3427.0, 1333.0, 1505.0, 771.0, 1144.0, 1125.0, 1197.0, 1726.0, 395.0, 669.0, 661.0, 901.0, 598.0, 1050.0, 589.0, 778.0, 307.0, 761.0, 549.0, 514.0, 443.0, 268.0, 481.0, 473.0, 781.0, 437.0, 524.0, 220.0, 522.0, 249.0, 760.7497074031567, 521.4888539664895, 424.8329569592866, 336.38677694050205, 318.4207652194279, 346.44009573833273, 298.762823123848, 292.5779207976132, 287.2984991513653, 262.3380335378017, 260.2083750152144, 251.24319864802052, 259.6439689206373, 243.63910084940153, 242.3692022292892, 899.1214671964299, 232.53182958615977, 229.99064381880115, 221.45782260338783, 197.1334030350804, 192.66496172938437, 200.98980572843035, 184.72934804664, 170.8404544624685 ...

# %%
pyLDAvis.save_html(model, 'data/JSON_files/models/all_posts.html')
